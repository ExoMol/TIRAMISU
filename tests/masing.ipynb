# %%
import math
import pickle

import numba
import typing as t
import numpy as np
import numpy.typing as npt
import pandas as pd
import astropy.constants as ac
import astropy.units as u
import matplotlib.pyplot as plt
from linelisttools.plot import get_vibrant_colors

from scipy.optimize import minimize, least_squares
from scipy.integrate import simpson

# %%
root_dir = r"/mnt/c/PhD/NLTE/Models/KELT-20b/"
oh_scale = 1
bl = 20
masing_folder = "outputs_new6"
# lte_emission = np.loadtxt(rf"{root_dir}{oh_scale}xOH_bL{bl}/{masing_folder}/KELT-20b_LTE_intensity_up.txt")
# nlte_emission_new = np.loadtxt(rf"{root_dir}{oh_scale}xOH_bL{bl}/{masing_folder}/KELT-20b_nLTE_intensity_up.txt")
# lte_wn_grid = np.loadtxt(rf"{root_dir}{oh_scale}xOH_bL{bl}/{masing_folder}/KELT-20b_LTE_cont_{oh_scale}xOH_boundaryL{bl}.txt")[:, 0]
# wn_grid = np.loadtxt(rf"{root_dir}{oh_scale}xOH_bL{bl}/{masing_folder}/KELT-20b_cont_{oh_scale}xOH_boundaryL{bl}_transmission_highres.txt")[:, 0]
pops = pickle.load(open(r"/mnt/c/PhD/NLTE/Models/KELT-20b/1xOH_bL20/outputs_new6/KELT-20b_cont_boundaryL20_pop_matrix.pickle", "rb"))
